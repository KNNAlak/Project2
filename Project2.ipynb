# %%
import requests
from bs4 import BeautifulSoup
import csv
   
URL = "http://www.values.com/inspirational-quotes"
r = requests.get(URL)
   
soup = BeautifulSoup(r.content, 'html5lib')
   
quotes=[]  # a list to store quotes
   
table = soup.find('div', attrs = {'id':'all_quotes'}) 
   
for row in table.findAll('div',
                         attrs = {'class':'col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top'}):
    quote = {}
    quote['theme'] = row.h5.text
    quote['url'] = row.a['href']
    quote['img'] = row.img['src']
    quote['lines'] = row.img['alt'].split(" #")[0]
    quote['author'] = row.img['alt'].split(" #")[1]
    quotes.append(quote)
   
filename = 'inspirational_quotes.csv'
with open(filename, 'w', newline='') as f:
    w = csv.DictWriter(f,['theme','url','img','lines','author'])
    w.writeheader()
    for quote in quotes:
        w.writerow(quote)

# %%
table = soup.find('div', attrs = {'id':'all_quotes'})

# %%
for row in table.find_all_next('div', attrs = {'class': 'col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top'}):
    quote = {}
    quote['theme'] = row.h5.text
    quote['url'] = row.a['href']
    quote['img'] = row.img['src']
    quote['lines'] = row.img['alt'].split(" #")[0]
    quote['author'] = row.img['alt'].split(" #")[1]
    quotes.append(quote)

# %%
quote['url'] = row.a['href']

# %%
filename = 'inspirational_quotes.csv'
with open(filename, 'w', newline='') as f:
    w = csv.DictWriter(f,['theme','url','img','lines','author'])
    w.writeheader()
    for quote in quotes:
        w.writerow(quote)

# %%
import pandas as pd
pd.read_csv('inspirational_quotes.csv')
# Out:
#           theme                                                url  \
# 0         PEACE  /inspirational-quotes/8310-peace-is-its-own-re...
# 1         PEACE  /inspirational-quotes/7582-it-isn-t-enough-to-...
# 2      OPTIMISM  /inspirational-quotes/8308-optimism-is-a-strat...
# 3      OPTIMISM  /inspirational-quotes/7376-and-you-ask-what-if...
# 4      OPTIMISM  /inspirational-quotes/8309-it-s-not-that-optim...
# ..          ...                                                ...
# 59  INSPIRATION  /inspirational-quotes/8298-though-no-one-can-g...
# 60  INSPIRATION  /inspirational-quotes/8297-a-highly-developed-...
# 61  INSPIRATION  /inspirational-quotes/7066-just-don-t-give-up-...
# 62  INSPIRATION  /inspirational-quotes/8296-when-we-strive-to-b...
# 63  INSPIRATION  /inspirational-quotes/8299-the-most-important-...
#
#                                                   img  \
# 0   https://assets.passiton.com/quotes/quote_artwo...
# 1   https://assets.passiton.com/quotes/quote_artwo...
# 2   https://assets.passiton.com/quotes/quote_artwo...
# 3   https://assets.passiton.com/quotes/quote_artwo...
# 4   https://assets.passiton.com/quotes/quote_artwo...
# ..                                                ...
# 59  https://assets.passiton.com/quotes/quote_artwo...
# 60  https://assets.passiton.com/quotes/quote_artwo...
# 61  https://assets.passiton.com/quotes/quote_artwo...
# 62  https://assets.passiton.com/quotes/quote_artwo...
# 63  https://assets.passiton.com/quotes/quote_artwo...
#
#                                                 lines  \
# 0                            Peace is its own reward.
# 1   It isn’t enough to talk about peace. One must ...
# 2   Optimism is a strategy for making a better fut...
# 3   And you ask “what if I fall?" Oh but my darlin...
# 4   It’s not that optimism solves all of life’s pr...
# ..                                                ...
# 59  Though no one can go back and make a brand new...
# 60  A highly developed values system is like a com...
# 61  Just don’t give up trying what you really want...
# 62  When we strive to become better than we are, e...
# 63   The most important thing is to try and inspir...
#
#                          author
# 0   <Author:0x00007f0d39bebc28>
# 1   <Author:0x00007f0d39c6e3a8>
# 2   <Author:0x00007f0d39cdb9f8>
# 3   <Author:0x00007f0d39da0320>
# 4   <Author:0x00007f0d39e32e00>
# ..                          ...
# 59  <Author:0x00007f0d3b365a70>
# 60  <Author:0x00007f0d3b612570>
# 61  <Author:0x00007f0d3af46a20>
# 62  <Author:0x00007f0d3b577d18>
# 63  <Author:0x00007f0d3b5184f8>
#
# [64 rows x 5 columns]
